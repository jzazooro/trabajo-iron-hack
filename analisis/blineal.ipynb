# %%
#leer el csv
import pandas as pd
data = pd.read_csv('limpiezarealizada.csv', delimiter=",")
print(data.head())

#analisis del csv
data.describe()
# Out:
#    Unnamed: 0  bedrooms  bathrooms  sqft_living floors  waterfront  view  \
# 0           0         3          1         1180      1           0     0
# 1           1         3          2         2570      2           0     0
# 2           2         2          1          770      1           0     0
# 3           3         4          3         1960      1           0     0
# 4           4         3          2         1680      1           0     0
#
#    grade  sqft_above  sqft_basement        zipcode  sqft_living15   price
# 0      7        1180              0  310612.755725           1340  221900
# 1      7        2170            400  469928.767726           1690  538000
# 2      6         770              0  462488.869258           2720  180000
# 3      7        1050            910  551768.520913           1360  604000
# 4      8        1680              0  685675.843537           1800  510000
#          Unnamed: 0      bedrooms     bathrooms   sqft_living    waterfront  \
# count  21597.000000  21597.000000  21597.000000  21597.000000  21597.000000
# mean   10798.000000      3.373200      2.059777   2080.321850      0.007547
# std     6234.661218      0.926299      0.754435    918.106125      0.086549
# min        0.000000      1.000000      0.000000    370.000000      0.000000
# 25%     5399.000000      3.000000      2.000000   1430.000000      0.000000
# 50%    10798.000000      3.000000      2.000000   1910.000000      0.000000
# 75%    16197.000000      4.000000      2.000000   2550.000000      0.000000
# max    21596.000000     33.000000      8.000000  13540.000000      1.000000
#
#                view         grade    sqft_above  sqft_basement       zipcode  \
# count  21597.000000  21597.000000  21597.000000   21597.000000  2.159700e+04
# mean       0.234292      7.657915   1788.596842     291.725008  5.402966e+05
# std        0.766390      1.173200    827.759761     442.667800  2.344425e+05
# min        0.000000      3.000000    370.000000       0.000000  2.342840e+05
# 25%        0.000000      7.000000   1190.000000       0.000000  3.594963e+05
# 50%        0.000000      7.000000   1560.000000       0.000000  4.936253e+05
# 75%        0.000000      8.000000   2210.000000     560.000000  6.452442e+05
# max        4.000000     13.000000   9410.000000    4820.000000  2.161300e+06
#
#        sqft_living15         price
# count   21597.000000  2.159700e+04
# mean     1986.620318  5.402966e+05
# std       685.230472  3.673681e+05
# min       399.000000  7.800000e+04
# 25%      1490.000000  3.220000e+05
# 50%      1840.000000  4.500000e+05
# 75%      2360.000000  6.450000e+05
# max      6210.000000  7.700000e+06

# %%
#sacar una regresion  del csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import ARDRegression
from sklearn.linear_model import PassiveAggressiveRegressor
from sklearn.linear_model import TheilSenRegressor
from sklearn.linear_model import RANSACRegressor
from sklearn.linear_model import HuberRegressor

#graficar
plt.scatter(data['bedrooms'], data['price'])
plt.show()

#regresion lineal
x = data['bedrooms'].values.reshape(-1, 1)
y = data['price'].values.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

regresion = LinearRegression()
regresion.fit(x_train, y_train)

#graficar
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

#predecir
print("prediccion")
y_pred = regresion.predict(x_test)
#precision de la prediccion
print('Precisión de la regresión lineal: ', regresion.score(x_train, y_train))

#graficar

plt.scatter(x_test, y_test, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()


#r2
print('R2: ', r2_score(y_test, y_pred))
# Out:
# prediccion
# Precisión de la regresión lineal:  0.09544245029096499
# R2:  0.09438464156020587

# %%
#sacar una regresion  del csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import ARDRegression
from sklearn.linear_model import PassiveAggressiveRegressor
from sklearn.linear_model import TheilSenRegressor
from sklearn.linear_model import RANSACRegressor
from sklearn.linear_model import HuberRegressor

#graficar
plt.scatter(data['bathrooms'], data['price'])
plt.show()

#regresion lineal
x = data['bathrooms'].values.reshape(-1, 1)
y = data['price'].values.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

regresion = LinearRegression()
regresion.fit(x_train, y_train)

#graficar
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

#predecir
print("prediccion")
y_pred = regresion.predict(x_test)
#precision de la prediccion
print('Precisión de la regresión lineal: ', regresion.score(x_train, y_train))

#graficar

plt.scatter(x_test, y_test, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()


#r2
print('R2: ', r2_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5608/2329083589.py in <module>
#      23
#      24 #graficar
# ---> 25 plt.scatter(data['bathrooms'], data['price'])
#      26 plt.show()
#      27
#
# NameError: name 'data' is not defined

# %%
#sacar una regresion  del csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import ARDRegression
from sklearn.linear_model import PassiveAggressiveRegressor
from sklearn.linear_model import TheilSenRegressor
from sklearn.linear_model import RANSACRegressor
from sklearn.linear_model import HuberRegressor

#graficar
plt.scatter(data['sqft_living'], data['price'])
plt.show()

#regresion lineal
x = data['sqft_living'].values.reshape(-1, 1)
y = data['price'].values.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

regresion = LinearRegression()
regresion.fit(x_train, y_train)

#graficar
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

#predecir
print("prediccion")
y_pred = regresion.predict(x_test)
#precision de la prediccion
print('Precisión de la regresión lineal: ', regresion.score(x_train, y_train))

#graficar

plt.scatter(x_test, y_test, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()


#r2
print('R2: ', r2_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5608/4069097911.py in <module>
#      23
#      24 #graficar
# ---> 25 plt.scatter(data['sqft_living'], data['price'])
#      26 plt.show()
#      27
#
# NameError: name 'data' is not defined

# %%
#sacar una regresion  del csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import ARDRegression
from sklearn.linear_model import PassiveAggressiveRegressor
from sklearn.linear_model import TheilSenRegressor
from sklearn.linear_model import RANSACRegressor
from sklearn.linear_model import HuberRegressor

#graficar
plt.scatter(data['floors'], data['price'])
plt.show()

#regresion lineal
x = data['floors'].values.reshape(-1, 1)
y = data['price'].values.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

regresion = LinearRegression()
regresion.fit(x_train, y_train)

#graficar
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

#predecir
print("prediccion")
y_pred = regresion.predict(x_test)
#precision de la prediccion
print('Precisión de la regresión lineal: ', regresion.score(x_train, y_train))

#graficar

plt.scatter(x_test, y_test, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()


#r2
print('R2: ', r2_score(y_test, y_pred))
# Out:
# prediccion
# Precisión de la regresión lineal:  0.09544245029096499
# R2:  0.09438464156020587

# %%
#sacar una regresion  del csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import ARDRegression
from sklearn.linear_model import PassiveAggressiveRegressor
from sklearn.linear_model import TheilSenRegressor
from sklearn.linear_model import RANSACRegressor
from sklearn.linear_model import HuberRegressor

#graficar
plt.scatter(data['waterfront'], data['price'])
plt.show()

#regresion lineal
x = data['waterfront'].values.reshape(-1, 1)
y = data['price'].values.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

regresion = LinearRegression()
regresion.fit(x_train, y_train)

#graficar
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

#predecir
print("prediccion")
y_pred = regresion.predict(x_test)
#precision de la prediccion
print('Precisión de la regresión lineal: ', regresion.score(x_train, y_train))

#graficar

plt.scatter(x_test, y_test, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()


#r2
print('R2: ', r2_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5608/2578854803.py in <module>
#      23
#      24 #graficar
# ---> 25 plt.scatter(data['waterfront'], data['price'])
#      26 plt.show()
#      27
#
# NameError: name 'data' is not defined

# %%
#sacar una regresion  del csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import ARDRegression
from sklearn.linear_model import PassiveAggressiveRegressor
from sklearn.linear_model import TheilSenRegressor
from sklearn.linear_model import RANSACRegressor
from sklearn.linear_model import HuberRegressor

#graficar
plt.scatter(data['view'], data['price'])
plt.show()

#regresion lineal
x = data['view'].values.reshape(-1, 1)
y = data['price'].values.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

regresion = LinearRegression()
regresion.fit(x_train, y_train)

#graficar
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

#predecir
print("prediccion")
y_pred = regresion.predict(x_test)
#precision de la prediccion
print('Precisión de la regresión lineal: ', regresion.score(x_train, y_train))

#graficar

plt.scatter(x_test, y_test, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()


#r2
print('R2: ', r2_score(y_test, y_pred))
# Out:
# prediccion
# Precisión de la regresión lineal:  0.09544245029096499
# R2:  0.09438464156020587

# %%
#sacar una regresion  del csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import ARDRegression
from sklearn.linear_model import PassiveAggressiveRegressor
from sklearn.linear_model import TheilSenRegressor
from sklearn.linear_model import RANSACRegressor
from sklearn.linear_model import HuberRegressor

#graficar
plt.scatter(data['grade'], data['price'])
plt.show()

#regresion lineal
x = data['grade'].values.reshape(-1, 1)
y = data['price'].values.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

regresion = LinearRegression()
regresion.fit(x_train, y_train)

#graficar
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

#predecir
print("prediccion")
y_pred = regresion.predict(x_test)
#precision de la prediccion
print('Precisión de la regresión lineal: ', regresion.score(x_train, y_train))

#graficar

plt.scatter(x_test, y_test, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()


#r2
print('R2: ', r2_score(y_test, y_pred))
# Out:
# prediccion
# Precisión de la regresión lineal:  0.09544245029096499
# R2:  0.09438464156020587

# %%
#sacar una regresion  del csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import ARDRegression
from sklearn.linear_model import PassiveAggressiveRegressor
from sklearn.linear_model import TheilSenRegressor
from sklearn.linear_model import RANSACRegressor
from sklearn.linear_model import HuberRegressor

#graficar
plt.scatter(data['sqft_above'], data['price'])
plt.show()

#regresion lineal
x = data['sqft_above'].values.reshape(-1, 1)
y = data['price'].values.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

regresion = LinearRegression()
regresion.fit(x_train, y_train)

#graficar
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

#predecir
print("prediccion")
y_pred = regresion.predict(x_test)
#precision de la prediccion
print('Precisión de la regresión lineal: ', regresion.score(x_train, y_train))

#graficar

plt.scatter(x_test, y_test, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()


#r2
print('R2: ', r2_score(y_test, y_pred))
# Out:
# prediccion
# Precisión de la regresión lineal:  0.09544245029096499
# R2:  0.09438464156020587

# %%
#sacar una regresion  del csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import ARDRegression
from sklearn.linear_model import PassiveAggressiveRegressor
from sklearn.linear_model import TheilSenRegressor
from sklearn.linear_model import RANSACRegressor
from sklearn.linear_model import HuberRegressor

#graficar
plt.scatter(data['sqft_basement'], data['price'])
plt.show()

#regresion lineal
x = data['sqft_basement'].values.reshape(-1, 1)
y = data['price'].values.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

regresion = LinearRegression()
regresion.fit(x_train, y_train)

#graficar
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

#predecir
print("prediccion")
y_pred = regresion.predict(x_test)
#precision de la prediccion
print('Precisión de la regresión lineal: ', regresion.score(x_train, y_train))

#graficar

plt.scatter(x_test, y_test, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()


#r2
print('R2: ', r2_score(y_test, y_pred))
# Out:
# prediccion
# Precisión de la regresión lineal:  0.09544245029096499
# R2:  0.09438464156020587

# %%
#sacar una regresion  del csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import ARDRegression
from sklearn.linear_model import PassiveAggressiveRegressor
from sklearn.linear_model import TheilSenRegressor
from sklearn.linear_model import RANSACRegressor
from sklearn.linear_model import HuberRegressor

#graficar
plt.scatter(data['zipcode'], data['price'])
plt.show()

#regresion lineal
x = data['zipcode'].values.reshape(-1, 1)
y = data['price'].values.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

regresion = LinearRegression()
regresion.fit(x_train, y_train)

#graficar
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

#predecir
print("prediccion")
y_pred = regresion.predict(x_test)
#precision de la prediccion
print('Precisión de la regresión lineal: ', regresion.score(x_train, y_train))

#graficar

plt.scatter(x_test, y_test, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()


#r2
print('R2: ', r2_score(y_test, y_pred))
# Out:
# prediccion
# Precisión de la regresión lineal:  0.09544245029096499
# R2:  0.09438464156020587

# %%
#sacar una regresion  del csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import ARDRegression
from sklearn.linear_model import PassiveAggressiveRegressor
from sklearn.linear_model import TheilSenRegressor
from sklearn.linear_model import RANSACRegressor
from sklearn.linear_model import HuberRegressor

#graficar
plt.scatter(data['sqft_living15'], data['price'])
plt.show()

#regresion lineal
x = data['sqft_living15'].values.reshape(-1, 1)
y = data['price'].values.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

regresion = LinearRegression()
regresion.fit(x_train, y_train)

#graficar
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

#predecir
print("prediccion")
y_pred = regresion.predict(x_test)
#precision de la prediccion
print('Precisión de la regresión lineal: ', regresion.score(x_train, y_train))

#graficar

plt.scatter(x_test, y_test, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()


#r2
print('R2: ', r2_score(y_test, y_pred))
# Out:
# prediccion
# Precisión de la regresión lineal:  0.09544245029096499
# R2:  0.09438464156020587
